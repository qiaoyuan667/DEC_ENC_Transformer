# %%
import sys
import os

# Get the current directory
current_path = os.getcwd()

# Add the current directory to sys.path
sys.path.append(current_path)

# Now you can import modules from the current directory

# %%
from Timer import Model
import torch
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import math
import matplotlib.pyplot as plt

# Define the data generation function
def generate_data(num_points):
    x = np.linspace(0, 2 * math.pi*20, num_points)
    sine_data = np.sin(x)+np.sin(2*x)+np.sin(0.05*x)
    cosine_data = np.cos(x)
    return np.array(list(zip(sine_data, cosine_data)))

# Define a simple Time Series Dataset
class TimeSeriesDataset(Dataset):
    def __init__(self, data, input_len, output_len):
        self.data = data
        self.input_len = input_len
        self.output_len = output_len
    
    def __len__(self):
        return len(self.data) - self.input_len - self.output_len + 1

    def __getitem__(self, idx):
        x = self.data[idx:idx+self.input_len]
        y = self.data[idx+self.input_len:idx+self.input_len+self.output_len]
        return torch.tensor(x, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)

# Parameters for dataset
input_len = 40
output_len = 40
num_points = 1000

# Generate data
data = generate_data(num_points)

# Create dataset
dataset = TimeSeriesDataset(data, input_len, output_len)
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

# Split dataset
train_dataset, test_dataset = Subset(dataset, range(train_size)), Subset(dataset, range(train_size, len(dataset)))


plt.plot(data)
plt.axvline(x=train_size, color='gray', linestyle='--')  # Vertical line separating input and output



# Data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Assuming 'Model' is already defined and imported
class Args() :
    def __init__(self):
        self.task_name= 'forecast'
        self.ckpt_path= ''
        self.patch_len= 4
        self.d_model= 64
        self.d_ff= 256
        self.e_layers= 3
        self.n_heads= 4
        self.dropout= 0.1
        self.output_attention= False
        self.factor= False
        self.activation= False
        self.mask_flag = True

args = Args()
# Instantiate model
model = Model(args)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.MSELoss()

# %%
args = Args()
# Instantiate model
model = Model(args)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.MSELoss()

# 记录训练和测试损失

train_losses_Transformer = []
test_losses_Transformer = []

n_epochs = 100
for epoch in range(n_epochs):
    
   
    
    # 训练Transformer模型
    model.train()
    train_loss_Transformer = 0
    for X_train, y_train in train_loader:
        optimizer.zero_grad()
        output = model(X_train, None, None, None)
        loss = criterion(output, y_train)
        loss.backward()
        optimizer.step()
        train_loss_Transformer += loss.item() * len(X_train)
    train_losses_Transformer.append(train_loss_Transformer / len(train_dataset))
    
    model.eval()
    test_loss_Transformer = 0
    with torch.no_grad():
        for X_test, y_test in test_loader:
            output = model(X_test, None, None, None)
            loss = criterion(output, y_test)
            test_loss_Transformer += loss.item() * len(X_test)
    test_losses_Transformer.append(test_loss_Transformer / len(test_dataset))
    
    if (epoch + 1) % 10 == 0:
        print(f'Epoch {epoch + 1}/{n_epochs}, Transformer Train Loss: {train_losses_Transformer[-1]:.4f}, Transformer Test Loss: {test_losses_Transformer[-1]:.4f}')

# 绘制训练损失和测试损失曲线
plt.figure(figsize=(12, 6))
plt.plot(range(n_epochs), train_losses_Transformer, label='Transformer Train Loss')
plt.plot(range(n_epochs), test_losses_Transformer, label='Transformer Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 10/100, Transformer Train Loss: 0.2164, Transformer Test Loss: 0.1701
# Epoch 20/100, Transformer Train Loss: 0.1361, Transformer Test Loss: 0.1224
# Epoch 30/100, Transformer Train Loss: 0.0969, Transformer Test Loss: 0.0997
# Epoch 40/100, Transformer Train Loss: 0.0752, Transformer Test Loss: 0.0542
# Epoch 50/100, Transformer Train Loss: 0.0673, Transformer Test Loss: 0.0521
# Epoch 60/100, Transformer Train Loss: 0.0558, Transformer Test Loss: 0.0497
# Epoch 70/100, Transformer Train Loss: 0.0481, Transformer Test Loss: 0.0596
# Epoch 80/100, Transformer Train Loss: 0.0454, Transformer Test Loss: 0.0527
# Epoch 90/100, Transformer Train Loss: 0.0456, Transformer Test Loss: 0.0629
# Epoch 100/100, Transformer Train Loss: 0.0374, Transformer Test Loss: 0.0373

# %%
import random
# Randomly select data samples and visualize results
input_seq, target_seq = next(iter(test_loader))
output = model(input_seq,None,None,None)

# Randomly select 3 samples to visualize
sample_indices = random.sample(range(input_seq.size(0)), 3)

fig, axs = plt.subplots(1, 3, figsize=(16, 4))
for idx, i in enumerate(sample_indices):
    axs[idx].plot(range(input_len), input_seq[i].numpy(), label='Input')
    axs[idx].plot(range(input_len, input_len + output_len), target_seq[i].detach().numpy(), label='Actual')
    axs[idx].plot(range(input_len, input_len + output_len), output[i].detach().numpy(), label='Predicted')
    axs[idx].axvline(x=input_len, color='gray', linestyle='--')  # Vertical line separating input and output
    axs[idx].set_title(f'Sample {i+1}')
    axs[idx].set_xlabel('Time Step')
    axs[idx].set_ylabel('Value')
    axs[idx].legend()

plt.tight_layout()
plt.show()

# %%
from TrmEncoder import Model
import torch
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import math

# Assuming 'Model' is already defined and imported
class Args() :
    def __init__(self):
        self.task_name= 'forecast'
        self.ckpt_path= ''
        self.seq_len= 40
        self.pred_len= 40
        self.patch_len= 4
        self.d_model= 64
        self.d_ff= 256
        self.e_layers= 3
        self.n_heads= 4
        self.dropout= 0.1
        self.output_attention= False
        self.factor= False
        self.activation= False

args = Args()
# Instantiate model
model_enc = Model(args)
optimizer = torch.optim.Adam(model_enc.parameters(), lr=0.001)
criterion = torch.nn.MSELoss()

# %%
args = Args()
# Instantiate model
model = Model(args)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.MSELoss()

# 记录训练和测试损失

train_losses_Transformer = []
test_losses_Transformer = []

n_epochs = 100
for epoch in range(n_epochs):
    
   
    
    # 训练Transformer模型
    model.train()
    train_loss_Transformer = 0
    for X_train, y_train in train_loader:
        optimizer.zero_grad()
        output = model(X_train, None, None, None)
        loss = criterion(output, y_train)
        loss.backward()
        optimizer.step()
        train_loss_Transformer += loss.item() * len(X_train)
    train_losses_Transformer.append(train_loss_Transformer / len(train_dataset))
    
    model.eval()
    test_loss_Transformer = 0
    with torch.no_grad():
        for X_test, y_test in test_loader:
            output = model(X_test, None, None, None)
            loss = criterion(output, y_test)
            test_loss_Transformer += loss.item() * len(X_test)
    test_losses_Transformer.append(test_loss_Transformer / len(test_dataset))
    
    if (epoch + 1) % 10 == 0:
        print(f'Epoch {epoch + 1}/{n_epochs}, Transformer Train Loss: {train_losses_Transformer[-1]:.4f}, Transformer Test Loss: {test_losses_Transformer[-1]:.4f}')

# 绘制训练损失和测试损失曲线
plt.figure(figsize=(12, 6))
plt.plot(range(n_epochs), train_losses_Transformer, label='Transformer Train Loss')
plt.plot(range(n_epochs), test_losses_Transformer, label='Transformer Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 10/100, Transformer Train Loss: 0.1026, Transformer Test Loss: 0.0293
# Epoch 20/100, Transformer Train Loss: 0.0994, Transformer Test Loss: 0.0422
# Epoch 30/100, Transformer Train Loss: 0.0969, Transformer Test Loss: 0.0354
# Epoch 40/100, Transformer Train Loss: 0.0946, Transformer Test Loss: 0.0349
# Epoch 50/100, Transformer Train Loss: 0.0922, Transformer Test Loss: 0.0307
# Epoch 60/100, Transformer Train Loss: 0.0901, Transformer Test Loss: 0.0219
# Epoch 70/100, Transformer Train Loss: 0.0877, Transformer Test Loss: 0.0146
# Epoch 80/100, Transformer Train Loss: 0.0850, Transformer Test Loss: 0.0128
# Epoch 90/100, Transformer Train Loss: 0.0867, Transformer Test Loss: 0.0107
# Epoch 100/100, Transformer Train Loss: 0.0839, Transformer Test Loss: 0.0093

# %%
import random
# Randomly select data samples and visualize results
input_seq, target_seq = next(iter(test_loader))
output = model(input_seq,None,None,None)

# Randomly select 3 samples to visualize
sample_indices = random.sample(range(input_seq.size(0)), 3)

fig, axs = plt.subplots(1, 3, figsize=(16, 4))
for idx, i in enumerate(sample_indices):
    axs[idx].plot(range(input_len), input_seq[i].numpy(), label='Input')
    axs[idx].plot(range(input_len, input_len + output_len), target_seq[i].detach().numpy(), label='Actual')
    axs[idx].plot(range(input_len, input_len + output_len), output[i].detach().numpy(), label='Predicted')
    axs[idx].axvline(x=input_len, color='gray', linestyle='--')  # Vertical line separating input and output
    axs[idx].set_title(f'Sample {i+1}')
    axs[idx].set_xlabel('Time Step')
    axs[idx].set_ylabel('Value')
    axs[idx].legend()

plt.tight_layout()
plt.show()
